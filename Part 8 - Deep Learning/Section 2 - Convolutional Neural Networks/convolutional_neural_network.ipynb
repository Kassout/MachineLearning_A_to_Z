# %% [markdown]
# # Convolutional Neural Network
#
# ## Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
tf.__version__
# Out:
# '2.2.0'

# %% [markdown]
# # Part 1 - Data Preprocessing
#
# ## Preprocessing the Training set
#
# Class notes:
# * Image augmentation to prevent overfitting

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
training_set = train_datagen.flow_from_directory(
        'dataset/training_set/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ## Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
        'dataset/test_set//',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# # Part 2 - Building the CNN
#
# ## Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ## Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=(64, 64, 3)))

# %% [markdown]
# ## Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ## Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ## Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ## Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ## Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # Part 3 - Training the CNN
#
# ## Compiling the CNN

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.6630 - accuracy: 0.5959 - val_loss: 0.6065 - val_accuracy: 0.6590
# Epoch 2/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.6039 - accuracy: 0.6784 - val_loss: 0.5744 - val_accuracy: 0.7010
# Epoch 3/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.5670 - accuracy: 0.7035 - val_loss: 0.5880 - val_accuracy: 0.7085
# Epoch 4/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.5326 - accuracy: 0.7354 - val_loss: 0.5200 - val_accuracy: 0.7505
# Epoch 5/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.4996 - accuracy: 0.7524 - val_loss: 0.5061 - val_accuracy: 0.7620
# Epoch 6/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.4746 - accuracy: 0.7757 - val_loss: 0.5418 - val_accuracy: 0.7230
# Epoch 7/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.4565 - accuracy: 0.7856 - val_loss: 0.4788 - val_accuracy: 0.7840
# Epoch 8/25
#  - ETA: 4s - loss: 0.4573 - accuracy: 0.7885
# Epoch 9/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.4307 - accuracy: 0.7958 - val_loss: 0.5096 - val_accuracy: 0.7590
# Epoch 10/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.4270 - accuracy: 0.8011 - val_loss: 0.4516 - val_accuracy: 0.7920
# Epoch 11/25
# 250/250 [==============================] - 16s 62ms/step - loss: 0.4087 - accuracy: 0.8124 - val_loss: 0.4575 - val_accuracy: 0.7875
# Epoch 12/25
# 250/250 [==============================] - 16s 63ms/step - loss: 0.3911 - accuracy: 0.8205 - val_loss: 0.5277 - val_accuracy: 0.7680
# Epoch 13/25
#  - ETA: 5s - loss: 0.3681 - accuracy: 0.8330
# Epoch 14/25
#  - ETA: 10s - loss: 0.3380 - accuracy: 0.8492
# Epoch 15/25
# 250/250 [==============================] - 16s 63ms/step - loss: 0.3467 - accuracy: 0.8495 - val_loss: 0.4658 - val_accuracy: 0.7985
# Epoch 16/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.3414 - accuracy: 0.8470 - val_loss: 0.4542 - val_accuracy: 0.7925
# Epoch 17/25
# 250/250 [==============================] - 16s 62ms/step - loss: 0.3129 - accuracy: 0.8654 - val_loss: 0.4748 - val_accuracy: 0.7950
# Epoch 18/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.3091 - accuracy: 0.8691 - val_loss: 0.4517 - val_accuracy: 0.8060
# Epoch 19/25
# 250/250 [==============================] - 16s 62ms/step - loss: 0.2934 - accuracy: 0.8754 - val_loss: 0.4868 - val_accuracy: 0.8005
# Epoch 20/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.2767 - accuracy: 0.8806 - val_loss: 0.5461 - val_accuracy: 0.7775
# Epoch 21/25
#  - ETA: 11s - loss: 0.2513 - accuracy: 0.8960
# Epoch 22/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.2447 - accuracy: 0.8997 - val_loss: 0.4855 - val_accuracy: 0.8150
# Epoch 23/25
#  - ETA: 4s - loss: 0.2285 - accuracy: 0.9089
# Epoch 24/25
# 250/250 [==============================] - 15s 62ms/step - loss: 0.2144 - accuracy: 0.9126 - val_loss: 0.6076 - val_accuracy: 0.7925
# Epoch 25/25
# 250/250 [==============================] - 15s 61ms/step - loss: 0.2033 - accuracy: 0.9145 - val_loss: 0.5754 - val_accuracy: 0.8060

# %% [markdown]
# # Part 4 - Making a single prediction

# %%
test_image = image.load_img('dataset/single_prediction/cat_or_dog_4.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'

# %%
print(prediction)
# Out:
# cat
